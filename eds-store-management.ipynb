# %%
#import libraries

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
#load dataset 

df = pd.read_csv("/kaggle/input/store-management-dataset/Store_Management_System.csv")

# %%
#knowning our data

df.head()
# Out:
#   Order ID  Order Date   Ship Date   Customer Name Customer ID  \
# 0  ORD1000  2025-10-24  2025-10-30  David Andersen     CUST516
# 1  ORD1001  2025-10-05  2025-10-06      Laura Carr     CUST519
# 2  ORD1002  2025-01-20  2025-01-27  Heather Snyder     CUST531
# 3  ORD1003  2025-07-23  2025-07-27  Michelle Adams     CUST607
# 4  ORD1004  2024-11-12  2024-11-13        Joe Park     CUST143
#
#   Customer Segment         Category  Product Name Product ID Region  ...  \
# 0         Consumer      Electronics         Mouse   PROD1908   West  ...
# 1         Consumer      Electronics    Headphones   PROD8656  North  ...
# 2         Consumer  Office Supplies   File Folder   PROD1460   East  ...
# 3        Corporate  Office Supplies      Notebook   PROD3347   West  ...
# 4         Consumer        Furniture  Dining Table   PROD6982  North  ...
#
#   Sales Amount Cost Price   Profit  Payment Mode  Delivery Status  \
# 0      8337.00    6633.85  1703.15          Cash        Delivered
# 1      9340.80    8086.91  1253.89   Net banking        Delivered
# 2      8968.50    5533.06  3435.44    Debit card          Pending
# 3      1341.00     987.66   353.34           UPI        Cancelled
# 4     12548.55   10723.90  1824.65   Net banking         Returned
#
#               Supplier Name          Supplier Email  Stock Left Auto-Reorder  \
# 0  Rojas, Burch and Clayton     bobby19@gilbert.com          20           No
# 1             Summers-Baker    lindseygreen@ray.com          11           No
# 2                  Frey Ltd  laurencasey@garcia.biz           8          Yes
# 3            Pacheco-Powell     brian17@mendoza.com          21           No
# 4                Hall-Adams     kdavis@shepard.info          38           No
#
#   Recorder Quantity
# 0                 0
# 1                 0
# 2                22
# 3                 0
# 4                 0
#
# [5 rows x 25 columns]

# %%
df.dtypes
# Out:
# Order ID              object
# Order Date            object
# Ship Date             object
# Customer Name         object
# Customer ID           object
# Customer Segment      object
# Category              object
# Product Name          object
# Product ID            object
# Region                object
# State                 object
# City                  object
# Quantity               int64
# Unit Price             int64
# Discount (%)           int64
# Sales Amount         float64
# Cost Price           float64
# Profit               float64
# Payment Mode          object
# Delivery Status       object
# Supplier Name         object
# Supplier Email        object
# Stock Left             int64
# Auto-Reorder          object
# Recorder Quantity      int64
# dtype: object

# %%
df.sample()
# Out:
#     Order ID  Order Date   Ship Date Customer Name Customer ID  \
# 149  ORD1149  2025-10-05  2025-10-12   Summer Cook     CUST928
#
#     Customer Segment         Category Product Name Product ID Region  ...  \
# 149         Consumer  Office Supplies  File Folder   PROD1399  South  ...
#
#     Sales Amount Cost Price   Profit  Payment Mode  Delivery Status  \
# 149     12064.05   10406.12  1657.93           UPI        Delivered
#
#      Supplier Name            Supplier Email  Stock Left Auto-Reorder  \
# 149   Cannon Group  thomasangela@johnson.com          36           No
#
#     Recorder Quantity
# 149                 0
#
# [1 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           1000 non-null   object
#  1   Order Date         1000 non-null   object
#  2   Ship Date          1000 non-null   object
#  3   Customer Name      1000 non-null   object
#  4   Customer ID        1000 non-null   object
#  5   Customer Segment   1000 non-null   object
#  6   Category           1000 non-null   object
#  7   Product Name       1000 non-null   object
#  8   Product ID         1000 non-null   object
#  9   Region             1000 non-null   object
#  10  State              1000 non-null   object
#  11  City               1000 non-null   object
#  12  Quantity           1000 non-null   int64
#  13  Unit Price         1000 non-null   int64
#  14  Discount (%)       1000 non-null   int64
#  15  Sales Amount       1000 non-null   float64
#  16  Cost Price         1000 non-null   float64
#  17  Profit             1000 non-null   float64
#  18  Payment Mode       1000 non-null   object
#  19  Delivery Status    1000 non-null   object
#  20  Supplier Name      1000 non-null   object
#  21  Supplier Email     1000 non-null   object
#  22  Stock Left         1000 non-null   int64
#  23  Auto-Reorder       1000 non-null   object
#  24  Recorder Quantity  1000 non-null   int64
# dtypes: float64(3), int64(5), object(17)
# memory usage: 195.4+ KB

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Customer Name', 'Customer ID',
#        'Customer Segment', 'Category', 'Product Name', 'Product ID', 'Region',
#        'State', 'City', 'Quantity', 'Unit Price', 'Discount (%)',
#        'Sales Amount', 'Cost Price', 'Profit', 'Payment Mode',
#        'Delivery Status', 'Supplier Name', 'Supplier Email', 'Stock Left',
#        'Auto-Reorder', 'Recorder Quantity'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 25)

# %%
df.describe(include = 'object')
# Out:
#        Order ID  Order Date   Ship Date Customer Name Customer ID  \
# count      1000        1000        1000          1000        1000
# unique     1000         338         345           989         603
# top     ORD1999  2025-01-14  2025-01-18   Kelly Smith     CUST248
# freq          1           9           7             3           5
#
#        Customer Segment         Category Product Name Product ID Region  \
# count              1000             1000         1000       1000   1000
# unique                3                4           20        942      4
# top            Consumer  Office Supplies          Pen   PROD2409   West
# freq                356              283           66          3    271
#
#               State          City Payment Mode Delivery Status Supplier Name  \
# count          1000          1000         1000            1000          1000
# unique           50           960            4               4           973
# top     Mississippi  West Michael  Net banking        Returned   Johnson PLC
# freq             34             4          260             265             3
#
#                          Supplier Email Auto-Reorder
# count                              1000         1000
# unique                             1000            2
# top     ischmidt@rodriguez-marshall.com           No
# freq                                  1          813

# %%
#data analysis

df.isnull().sum()
# Out:
# Order ID             0
# Order Date           0
# Ship Date            0
# Customer Name        0
# Customer ID          0
# Customer Segment     0
# Category             0
# Product Name         0
# Product ID           0
# Region               0
# State                0
# City                 0
# Quantity             0
# Unit Price           0
# Discount (%)         0
# Sales Amount         0
# Cost Price           0
# Profit               0
# Payment Mode         0
# Delivery Status      0
# Supplier Name        0
# Supplier Email       0
# Stock Left           0
# Auto-Reorder         0
# Recorder Quantity    0
# dtype: int64

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

print(f"Order Date: {df['Order Date'].dtype}")
print(f"Ship Date: {df['Ship Date'].dtype}")
# Out:
# Order Date: datetime64[ns]
# Ship Date: datetime64[ns]

# %%
#univariate analysis(analysis i=on one variable)

categorical_cols = ['Customer Segment', 'Category', 'Region', 'Payment Mode', 'Delivery Status', 'Auto-Reorder']

for col in categorical_cols:
    print(f"\n---{col}---")
    print(df[col].value_counts())
    
    #visulaization
    plt.figure(figsize=(6,6))
    df[col].value_counts().plot(kind='bar', color='blue')
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()
# Out:
# ---Customer Segment---
# Customer Segment
# Consumer       356
# Corporate      332
# Home Office    312
# Name: count, dtype: int64
# ---Category---
# Category
# Office Supplies    283
# Grocery            256
# Electronics        233
# Furniture          228
# Name: count, dtype: int64
# ---Region---
# Region
# West     271
# North    263
# East     238
# South    228
# Name: count, dtype: int64
# ---Payment Mode---
# Payment Mode
# Net banking    260
# Cash           258
# Debit card     258
# UPI            224
# Name: count, dtype: int64
# ---Delivery Status---
# Delivery Status
# Returned     265
# Cancelled    249
# Pending      244
# Delivered    242
# Name: count, dtype: int64
# ---Auto-Reorder---
# Auto-Reorder
# No     813
# Yes    187
# Name: count, dtype: int64

# %%
numerical_cols = ['Quantity', 'Unit Price', 'Discount (%)', 'Sales Amount', 'Cost Price', 'Profit', 'Stock Left', 'Recorder Quantity']

for col in numerical_cols:
    print(f"\n---{col}---\n")
    print(f"Mean: {df[col].mean():.2f}")
    print(f"Median: {df[col].median():.2f}")
    print(f"Std Dev: {df[col].std():.2f}")
    print(f"Min: {df[col].min():.2f}")
    print(f"Max: {df[col].max():.2f}")

    #visualization
    plt.figure(figsize=(8,4))

    plt.subplot(1,2,1)
    df[col].hist(bins=30, color='green', alpha=0.8)
    plt.title(f"Distribution of {col}")

    plt.subplot(1,2,2)
    df.boxplot(column=col)
    plt.title(f'Boxplot of {col}')
    
    plt.show()
# Out:
# ---Quantity---
#
# Mean: 5.41
# Median: 5.00
# Std Dev: 2.85
# Min: 1.00
# Max: 10.00
# ---Unit Price---
#
# Mean: 2511.49
# Median: 2536.00
# Std Dev: 1414.06
# Min: 102.00
# Max: 4997.00
# ---Discount (%)---
#
# Mean: 21.74
# Median: 15.00
# Std Dev: 15.49
# Min: 5.00
# Max: 50.00
# ---Sales Amount---
#
# Mean: 10520.50
# Median: 7643.70
# Std Dev: 8899.12
# Min: 91.00
# Max: 44541.00
# ---Cost Price---
#
# Mean: 7891.59
# Median: 5893.60
# Std Dev: 6781.49
# Min: 63.46
# Max: 37669.47
# ---Profit---
#
# Mean: 2628.91
# Median: 1767.95
# Std Dev: 2547.95
# Min: 19.19
# Max: 14759.17
# ---Stock Left---
#
# Mean: 25.30
# Median: 25.00
# Std Dev: 14.71
# Min: 0.00
# Max: 50.00
# ---Recorder Quantity---
#
# Mean: 6.54
# Median: 0.00
# Std Dev: 14.16
# Min: 0.00
# Max: 50.00

# %%
#bivariate analysis (is the statistical analysis of 2 variables at the same time. The core purpose is to fine relationship between them)

print("\n SALES & PROFIT BY CATEGORY \n")

category_performance = df.groupby('Category').agg({
    'Sales Amount' : 'sum',
    'Profit' : 'sum',
    'Order ID' : 'count'
}).rename(columns = {'Order ID' : 'Order Count'})

category_performance['Profit Margin'] = (category_performance['Profit'] / category_performance['Sales Amount']) * 100
print(category_performance,'\n\n')

#Visualization
fig, axes = plt.subplots(2, 2, figsize = (15,12))

#Sales by Category
category_performance['Sales Amount'].plot(kind='bar', ax=axes[0,0],color='blue', alpha=0.7)
axes[0,0].set_title('Total Profit by Category')
axes[0,1].tick_params(axis='x', rotation = 30)

#Profit by Category
category_performance['Profit'].plot(kind='bar', ax=axes[0,1], color='green', alpha=0.7)
axes[0,1].set_title('Total Profit by Category')
axes[0,1].tick_params(axis='x', rotation = 30)

#Profit Margin
category_performance['Profit Margin'].plot(kind='bar', ax=axes[1,0], color='orange', alpha=0.7)
axes[1,0].set_title('Profit Margin by Category(%)')
axes[1,0].tick_params(axis='x', rotation = 30)


#Order Count
category_performance['Order Count'].plot(kind='bar', ax=axes[1,1], color='red', alpha=0.7)
axes[1,1].set_title('Order Count by Category')
axes[1,1].tick_params(axis='x', rotation = 30)

plt.tight_layout()
plt.show()
# Out:
#  SALES & PROFIT BY CATEGORY
#
#                  Sales Amount     Profit  Order Count  Profit Margin
# Category
# Electronics        2329946.25  577678.61          233      24.793645
# Furniture          2393904.50  594716.81          228      24.842963
# Grocery            2803239.05  735493.87          256      26.237287
# Office Supplies    2993411.25  721020.29          283      24.086911

# %%
#Regional Performance

print("\n REGIONAL PERFORMANCE \n")

regional_performance = df.groupby('Region').agg({
    'Sales Amount' : 'sum',
    'Profit' : 'sum',
    'Order ID' : 'count'
}).rename(columns = {'Order ID' : 'Order Count'})

regional_performance['Profit Margin'] = (regional_performance['Profit'] / regional_performance['Sales Amount'] * 100)
print(regional_performance,'\n\n')

#Visualization
plt.figure(figsize = (12,8))

plt.subplot(2,2,1)
regional_performance['Sales Amount'].plot(kind='pie', autopct='%1.1f%%')
plt.title('Sales Distribution by Region')

plt.subplot(2,2,2)
regional_performance['Profit'].plot(kind='pie', autopct='%1.1f%%')
plt.title('Profit Distribution by Region')

plt.subplot(2,2,3)
sns.barplot(x=regional_performance.index, y='Order Count', data = regional_performance)
plt.title('Order Count by Region')
plt.xticks(rotation = 30)

plt.subplot(2,2,4)
sns.barplot(x=regional_performance.index, y='Profit Margin', data = regional_performance)
plt.title('Profit Margin by Region(%)')
plt.xticks(rotation = 30)

plt.tight_layout()
plt.show()
# Out:
#  REGIONAL PERFORMANCE
#
#         Sales Amount     Profit  Order Count  Profit Margin
# Region
# East      2401820.80  604846.50          238      25.182832
# North     2635847.90  662324.54          263      25.127571
# South     2679543.90  678240.86          228      25.311803
# West      2803288.45  683497.68          271      24.381996

# %%
#Time Series Analysis

print("\n TIME SERIES ANALYSIS   \n")

#Extract time components
df['Order Month'] = df['Order Date'].dt.to_period('M')
df['Order Year'] = df['Order Date'].dt.year

#Monthly Trends
monthly_trends = df.groupby('Order Month').agg({
    'Sales Amount' : 'sum',
    'Profit' : 'sum',
    'Order ID' : 'count'
}).rename(columns={'Order ID' : 'Order Count'})

print("Monthly Trends")
print(monthly_trends.tail(10),'\n\n')

#Visualization
plt.figure(figsize=(15,10))

plt.subplot(3,1,1)
monthly_trends['Sales Amount'].plot(kind='line', color='blue', marker='o')
plt.title('Monthly Sale Trend')
plt.ylabel('Sales Amount')
plt.grid(True)

plt.subplot(3,1,2)
monthly_trends['Profit'].plot(kind='line', color='green', marker='o')
plt.title('Monthly Profit Trend')
plt.ylabel('Profit')
plt.grid(True)

plt.subplot(3,1,3)
monthly_trends['Order Count'].plot(kind='line', color='red', marker='o')
plt.title('Monthly Order Count Trend')
plt.ylabel('Order Count')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
#  TIME SERIES ANALYSIS
#
# Monthly Trends
#              Sales Amount     Profit  Order Count
# Order Month
# 2025-01        1132281.85  279629.43           95
# 2025-02         703910.20  175302.85           67
# 2025-03         688813.00  160824.35           69
# 2025-04         800949.75  209968.92           85
# 2025-05         796675.25  219763.74           88
# 2025-06         876831.35  204510.74           79
# 2025-07         821880.90  195100.30           86
# 2025-08         769104.30  194631.48           78
# 2025-09         931715.55  239212.95           87
# 2025-10         997836.15  260606.53           91

# %%
#Advance Analysis

print("\n CORRELATION ANALYSIS   \n")

#Select numerical columns for correlation
numerical_df = df[['Quantity', 'Unit Price', 'Discount (%)', 'Sales Amount', 'Cost Price', 'Profit']]

#Correlation Matrix
correlation_matrix = numerical_df.corr()
print("Correlation Matrix : ")
print(correlation_matrix, '\n\n')

#Heatmap
plt.figure(figsize =(10,8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0,
           square=True, linewidth=0.5)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()
# Out:
#  CORRELATION ANALYSIS
#
# Correlation Matrix :
#               Quantity  Unit Price  Discount (%)  Sales Amount  Cost Price  \
# Quantity      1.000000   -0.026818      0.012458      0.623873    0.607318
# Unit Price   -0.026818    1.000000     -0.010208      0.618293    0.609069
# Discount (%)  0.012458   -0.010208      1.000000     -0.225334   -0.230134
# Sales Amount  0.623873    0.618293     -0.225334      1.000000    0.983366
# Cost Price    0.607318    0.609069     -0.230134      0.983366    1.000000
# Profit        0.562569    0.538419     -0.174503      0.875385    0.773017
#
#                 Profit
# Quantity      0.562569
# Unit Price    0.538419
# Discount (%) -0.174503
# Sales Amount  0.875385
# Cost Price    0.773017
# Profit        1.000000
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
#Customer Segment Analysis

print("\n CUSTOMER SEGMENT ANALYSIS   \n")

segment_analysis = df.groupby('Customer Segment').agg({
    'Sales Amount' : ['sum','mean'],
    'Profit' : ['sum','mean'],
    'Order ID' : 'count',
    'Discount (%)' : 'mean'
}).round(2)

segment_analysis.columns = ['Total Sales', 'Avg Sales', 'Total Profit', 'Avg Profit', 'Order Count', 'Avg Discount']
print(segment_analysis,'\n\n')

#Visualization
fig, axes = plt.subplots(2,2, figsize = (15,10))

segment_analysis['Total Sales'].plot(kind='bar', ax=axes[0,0], color='blue')
axes[0,0].set_title('Total Sales by Customer Segemnt')
axes[0,0].tick_params(axis='x', rotation=30)

segment_analysis['Total Profit'].plot(kind='bar', ax=axes[0,1], color='green')
axes[0,1].set_title('Total Profit by Customer Segemnt')
axes[0,1].tick_params(axis='x', rotation=30)

segment_analysis['Avg Profit'].plot(kind='bar', ax=axes[1,0], color='orange')
axes[1,0].set_title('Average Profit by Customer Segemnt')
axes[1,0].tick_params(axis='x', rotation=30)


segment_analysis['Avg Discount'].plot(kind='bar', ax=axes[1,1], color='red')
axes[1,1].set_title('Average Discount by Customer Segemnt')
axes[1,1].tick_params(axis='x', rotation=30)

plt.tight_layout()
plt.show()
# Out:
#  CUSTOMER SEGMENT ANALYSIS
#
#                   Total Sales  Avg Sales  Total Profit  Avg Profit  \
# Customer Segment
# Consumer           3674937.95   10322.86     896200.36     2517.42
# Corporate          3568454.40   10748.36     911379.34     2745.12
# Home Office        3277108.70   10503.55     821329.88     2632.47
#
#                   Order Count  Avg Discount
# Customer Segment
# Consumer                  356         22.70
# Corporate                 332         21.57
# Home Office               312         20.83

# %%
#Key Insights and Summary

print("\n KEY INSIGHTS SUMMARY  \n")

#Overall Metrics
total_sales = df['Sales Amount'].sum()
total_profit = df['Profit'].sum()
total_orders = df['Order ID'].nunique()
avg_profit_margin = (total_profit / total_sales) * 100

print(f"OVERALL PERFORMANCE: \n")
print(f"Total Sales: ${total_sales:,.2f}")
print(f"Total Profit: ${total_profit:,.2f}")
print(f"Total Orders: {total_orders}")
print(f"Average Profit Margin: {avg_profit_margin:,.2f}%")

#Top Performing category
top_categories = df.groupby('Category')['Profit'].sum().sort_values(ascending=False)
print(f"\n TOP PERFORMING CATEGORIES : \n")
for i, (category, profit) in enumerate(top_categories.items(),1):
    print(f"{i}. {category}: ${profit:,.2f}")


#Regional Performance
best_region = df.groupby('Region')['Profit'].sum().idxmax()
print(f"\n BEST PERFORMING REGION: {best_region}")

#Delivery Performance
delivery_status = df['Delivery Status'].value_counts(normalize=True) * 100
print(f"\n DELIVERY STATUS:")
for status, percentage in delivery_status.items():
    print(f"{status}: {percentage:.1f}%")


#Customer Segements
best_segment = df.groupby('Customer Segment')['Profit'].sum().idxmax()
print(f"\n MOST PROFITABLE CUSTOMER SEGMENT: {best_segment}")

# %%
#Export results

analysis_results = {
    'total_sales' : total_sales,
    'total_profit' : total_profit,
    'total_orders' : total_orders,
    'avg_profit_margin' : avg_profit_margin,
    'top_category' : top_categories.index[0],
    'best_region' : best_region,
    'best_customer_segment' : best_segment
}

#Convert to Dataframe and Save 
results_df = pd.DataFrame([analysis_results])
results_df.to_csv('eda_analysis_summary.csv', index=False)
print("\n Analysis summary saved to 'eda_analysis_summary.csv'")
# Out:
#  Analysis summary saved to 'eda_analysis_summary.csv'
